# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
url = "https://www.baseball-reference.com/leagues/MLB/2019.shtml"
page = requests.get(url, verify=False)
soup = BeautifulSoup(page.content, 'html.parser')
# Out:
# /usr/local/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)

# %%
table = soup.find('table', {'id': 'teams_standard_batting'})

# %%
rows = []
for tr in table.find_all('tr'):
    row = []
    try:
        row.append(tr.find_all('a')[0].text)
    except:
        try:
            row.append(tr.find_all('em')[0].text)
        except: 
            row.append("TOTAL")

    for td in tr.find_all('td'):
        row.append(td.text.replace('\n', ''))
        if len(row) == 28:
            rows.append(row)

# %%
columns=["Tm","NumPlayers","BatAge","RunsPerGame","G","PA","AB","R","H","2B","3B","HR","RBI","SB","CS","BB","SO","BA","OBP","SLG","OPS","OPSAdjusted","TB","GDP","HBP","SH","SF","IBB","LOB"]
batting_df = pd.DataFrame(rows, columns=columns)

# %%
batting_df.tail()
# Out:
#        Tm NumPlayers BatAge RunsPerGame     G     PA     AB      R      H  \
# 27    TEX         38   29.3        5.58    78   3028   2678    435    687
# 28    TOR         45   26.6        4.08    78   2898   2616    318    589
# 29    WSN         40   28.8        4.97    77   2931   2597    383    660
# 30  LgAvg         39   28.2        4.78    78   2972   2650    371    664
# 31  TOTAL       1172   28.2        4.78  2328  89160  79507  11127  19916
#
#       2B  ...   SLG   OPS OPSAdjusted     TB   GDP  HBP   SH   SF  IBB    LOB
# 27   164  ...  .450  .784         100   1206    48   35   10   19   10    524
# 28   117  ...  .392  .685          85   1026    51   18    9   15    7    473
# 29   124  ...  .436  .762          94   1131    53   39   25   19   15    513
# 30   134  ...  .429  .751          97   1138    55   32   13   19   13    524
# 31  4018  ...  .429  .751          97  34133  1640  945  379  583  394  15729
#
# [5 rows x 29 columns]

# %%
url = "https://www.baseball-reference.com/leagues/MLB/2019-standard-pitching.shtml"
page = requests.get(url, verify=False)
soup = BeautifulSoup(page.content, 'html.parser')
# Out:
# /usr/local/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)

# %%
pitching_table = soup.find('table', {'id': 'teams_standard_pitching'})

# %%
rows = []
for tr in pitching_table.find_all('tr'):
    row = []
    try:
        row.append(tr.find_all('a')[0].text)
    except:
        try:
            row.append(tr.find_all('em')[0].text)
        except: 
            row.append("TOTAL")

    for td in tr.find_all('td'):
        row.append(td.text.replace('\n', ''))
        if len(row) == 36:
            rows.append(row)

# %%
columns = ["Tm","PitchersPerGame","PAge","RAPerGame","W","L","WinLossPct","ERA","G","GS","GF","CG","tSho","cSho","SV","IP","H","R","ER","HR","BB","IBB","SO","HBP","BK","WP","BF","ERAPlus","FIP","WHIP","H9","HR9","BB9","SO9","SOW","LOB"]
pitching_df = pd.DataFrame(rows, columns=columns)

# %%
pitching_df.tail()
# Out:
#        Tm PitchersPerGame  PAge RAPerGame     W     L WinLossPct   ERA     G  \
# 27    TEX              23  29.4      5.18    42    36       .538  4.87    78
# 28    TOR              27  28.3      5.17    29    49       .372  4.80    78
# 29    WSN              22  30.7      4.90    37    40       .481  4.66    77
# 30  LgAvg              22  28.6      4.78    39    39       .500  4.45    78
# 31  TOTAL             669  28.6      4.78  1163  1163       .500  4.45  2328
#
#       GS  ...     BF ERAPlus   FIP   WHIP   H9  HR9  BB9  SO9   SOW    LOB
# 27    78  ...   3058     102  4.77  1.452  9.5  1.5  3.6  8.4  2.33    563
# 28    78  ...   3039      94  4.86  1.440  9.1  1.5  3.9  8.4  2.15    561
# 29    77  ...   2941      99  4.20  1.332  8.7  1.3  3.3  9.6  2.90    526
# 30    78  ...   2972     101  4.46  1.331  8.6  1.4  3.3  8.8  2.63    524
# 31  2328  ...  89160     101  4.46  1.331  8.6  1.4  3.3  8.8  2.63  15729
#
# [5 rows x 36 columns]

# %%
url = "https://www.baseball-reference.com/leagues/MLB/2019-pitches-pitching.shtml"
page = requests.get(url, verify=False)
soup = BeautifulSoup(page.content, 'html.parser')
# Out:
# /usr/local/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)

# %%
pitches_pitching_table = soup.find('table', {'id': 'teams_pitches_pitching'})
rows = []
for tr in pitches_pitching_table.find_all('tr'):
    row = []
    try:
        row.append(tr.find_all('a')[0].text)
    except:
        try:
            row.append(tr.find_all('em')[0].text)
        except: 
            row.append("TOTAL")

    for td in tr.find_all('td'):
        row.append(td.text.replace('\n', ''))
        if len(row) == 31:
            rows.append(row)

# %%
columns = ["Tm","RunAllowedPerGame","PlateAppearances","Pit","PitPerPlateAppearance","Strikes","StrikePct","StrikeLookingPct","StrikeSwingingPct","StrikeFoulPct","BallsInPlayPct","StrikeSwungPct","IntentionalBallPct","PitchesSwungAtPct","ContactPct","1stPitchStrikePct","30CountSeenPct","30CountSeen","30StikeCount","02CountSeenPct","02CountSeen","02StrikeCount","02HitsAllowed","StrikeoutLooking","StrikeoutSwinging","StrikeoutLookingPct","3PitchStrikeout","4PitchWalk","PAu","Pitu","Stru"]
pitches_pitching_df = pd.DataFrame(rows, columns=columns)

# %%
pitches_pitching_df.tail()
# Out:
#        Tm RunAllowedPerGame PlateAppearances     Pit PitPerPlateAppearance  \
# 27    TEX              5.18             3065   12026                  3.92
# 28    TOR              5.17             3047   11917                  3.91
# 29    WSN              4.90             2946   11534                  3.92
# 30  LgAvg              4.78             2978   11642                  3.91
# 31  TOTAL              4.78            89335  349252                  3.91
#
#    Strikes StrikePct StrikeLookingPct StrikeSwingingPct StrikeFoulPct  ...  \
# 27    7593     63.1%            27.1%             17.2%         28.0%  ...
# 28    7387     62.0%            26.0%             19.0%         26.9%  ...
# 29    7357     63.8%            25.4%             20.8%         27.6%  ...
# 30    7405     63.6%            26.1%             18.9%         27.9%  ...
# 31  222155     63.6%            26.1%             18.9%         27.9%  ...
#
# ...

# %%
#Pitching Calculations
tmp_innings_pitched = pitching_df.iloc[31]["IP"]
tmp_innings_pitched
innings_pitched, partial_innings_pitched = tmp_innings_pitched.split(".")
print(innings_pitched)
ip = int(innings_pitched) + (int(partial_innings_pitched) * .33)
batters_faced = ((ip*2.82)+int(pitching_df.iloc[31]["H"])+int(pitching_df.iloc[31]["BB"]))/int(batting_df.iloc[31]["G"])
print(batters_faced)
aveNumOfPitchesAve = batters_faced * float(pitches_pitching_df.iloc[31]['PitPerPlateAppearance'])
# Out:
# 20768
# 37.02695876288659

# %%
aveNumOfPitchesAve
# Out:
# 144.7754087628866

# %%
onBaseAve = (int(pitching_df.iloc[31]["H"])+int(pitching_df.iloc[31]["BB"]))/(int(batting_df.iloc[31]["AB"])+int(batting_df.iloc[31]["BB"]))

# %%
print(f"public final static double onBaseAve = {onBaseAve};")
print(f"public final static double aveNumOfPitchesAve = {aveNumOfPitchesAve};")
# Out:
# public final static double onBaseAve = 0.31680500779601944;
# public final static double aveNumOfPitchesAve = 144.7754087628866;

# %%
print(f"public final static double onBaseAve = {onBaseAve};")
print(f"public final static double hitByPitchAve = {batting_df.iloc[30]['HBP']};")
print(f"public final static double sacFilesAve = {batting_df.iloc[30]['SF']};")
print(f"public final static double atBatsAve = {int(batting_df.iloc[30]['AB']) / 9};")    
print(f"public final static double hitsAve = {batting_df.iloc[30]['H']};")
print(f"public final static double doublesAve = {batting_df.iloc[30]['2B']};")
print(f"public final static double triplesAve = {batting_df.iloc[30]['3B']};")
print(f"public final static double hrAve = {batting_df.iloc[30]['HR']};")
print(f"public final static double singlesAve = {int(batting_df.iloc[30]['H'])-int(batting_df.iloc[30]['2B'])-int(batting_df.iloc[30]['3B'])-int(batting_df.iloc[30]['HR'])};")
print(f"public final static double bbAve = {batting_df.iloc[30]['BB']};")
print(f"public final static double tpaAve = {batting_df.iloc[30]['PA']};")
# Out:
# public final static double onBaseAve = 0.31680500779601944;
# public final static double hitByPitchAve = 32;
# public final static double sacFilesAve = 19;
# public final static double atBatsAve = 294.44444444444446;
# public final static double hitsAve = 664;
# public final static double doublesAve = 134;
# public final static double triplesAve = 12;
# public final static double hrAve = 105;
# public final static double singlesAve = 413;
# public final static double bbAve = 257;
# public final static double tpaAve = 2972;

# %%
2650/9
# Out:
# 294.44444444444446
